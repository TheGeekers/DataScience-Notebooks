# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Categorical Plots

# %% [markdown]
# ### barplot and countplot

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.max)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.min)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='smoker',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### boxplot and violinplot

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips[tips['day']=='Thur']['total_bill'].median()
# Out:
# 16.2

# %%
tips[tips['day']=='Thur']['total_bill'].std()
# Out:
# 7.886170333087847

# %%
tips[tips['day']=='Sun']['total_bill'].median()
# Out:
# 19.63

# %%
tips[tips['day']=='Sun']['total_bill'].std()
# Out:
# 8.832121828869889

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_19536\2944203433.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_19536\2944203433.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='coolwarm',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(y='day',x='total_bill',data=tips,palette='coolwarm',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='coolwarm',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='coolwarm')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_19536\2346646675.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='total_bill',data=tips,palette='coolwarm')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips[(tips['day']=='Fri')]['total_bill'].std()
# Out:
# 8.302659723217145

# %%
tips[(tips['day']=='Sat')]['total_bill'].std()
# Out:
# 9.480418641086723

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='Set1',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips[tips['day']=='Fri']['sex'].value_counts()
# Out:
# Male      10
# Female     9
# Name: sex, dtype: int64

# %%
tips[(tips['day']=='Fri')&(tips['sex']=='Female')]['total_bill'].agg({'max','min','std'})
# Out:
# min     5.750000
# std     4.788547
# max    22.750000
# Name: total_bill, dtype: float64

# %%
tips[(tips['day']=='Fri')&(tips['sex']=='Male')]['total_bill'].agg({'max','min','std'})
# Out:
# min     8.580000
# std    10.015847
# max    40.170000
# Name: total_bill, dtype: float64

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='Set1',hue='sex',split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='Set1')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_19536\3487123034.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='total_bill',data=tips,palette='Set1')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='Set1',hue='smoker',split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex')
plt.legend()

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',palette='Set1')
plt.legend()

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',palette='Set1',dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex',dodge=True,palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='tip',y='day',data=tips,palette='rainbow')
sns.swarmplot(x='tip',y='day',data=tips,color='black',size=3)
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\841563638.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='tip',y='day',data=tips,palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
tips.corr()
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\1579789445.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr())
# <Axes: >

# %%
sns.heatmap(tips.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\564889457.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.corr()
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\2457855925.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   flights.corr()
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(flights.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\2802442232.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(flights.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
piv = flights.pivot_table(values='passengers',index='month',columns='year')

# %%
sns.heatmap(piv)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(piv,cmap='magma',linecolor='white',linewidth=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(piv)

# %%
sns.clustermap(piv,cmap='coolwarm',standard_scale=1)

# %%
tips.corr()
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\1579789445.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr())
# <Axes: >

# %%
sns.heatmap(tips.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\564889457.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.corr()
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\2457855925.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   flights.corr()
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(flights.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\Lion\AppData\Local\Temp\ipykernel_10504\2802442232.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(flights.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
piv = flights.pivot_table(values='passengers',index='month',columns='year')

# %%
sns.heatmap(piv)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(piv,cmap='magma',linecolor='white',linewidth=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='bar')

# %%
sns.catplot(x='sex',data=tips,kind='count')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='swarm')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='strip',jitter=False)
